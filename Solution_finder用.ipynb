# %% [markdown]
# <a href="https://colab.research.google.com/github/selmtoe/A/blob/main/Solution_finder%E7%94%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install -y -qq openjdk-11-jre-headless unzip
# !java -version
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# openjdk version "11.0.28" 2025-07-15
# OpenJDK Runtime Environment (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1, mixed mode, sharing)

# %%
from google.colab import files
uploaded = files.upload()
# !unzip -o solution-finder-1.43.zip -d /content/sfinder
# !ls -la /content/sfinder
# Out:
#      <input type="file" id="files-ed918f93-ed4c-45a1-a42e-b4d840fa5e6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed918f93-ed4c-45a1-a42e-b4d840fa5e6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %%writefile /content/sfinder/input/field.txt
# 7
# X_________
# X________X
# XX____XXXX
# XX____XXXX
# XXXXX_XXXX
# XXXXX_XXXX
# XXXXX_XXXX
# Out:
# Overwriting /content/sfinder/input/field.txt

# %%
# !java -jar /content/sfinder/sfinder.jar percent \
  --field /content/sfinder/input/field.txt \
  --patterns "*p7"\
  > /content/sfinder_result.txt
# !head -n 500 /content/sfinder_result.txt
# Out:
# # Setup Field
# X_________
# X________X
# XX____XXXX
# XX____XXXX
# XXXXX_XXXX
# XXXXX_XXXX
# XXXXX_XXXX
#
# # Initialize / User-defined
# Max clear lines: 7
# Using hold: use
# Kicks: srs
# Drop: softdrop
# Searching patterns:
#   *p7
#
# # Initialize / System
# Threads = 2
# Version = 1.43
# Necessary Pieces = 7
#
# # Enumerate pieces
# Piece pop count = 7
# Searching pattern size (duplicate) = 5040
# Searching pattern size ( no dup. ) = 5040
#
# # Search
#   -> Stopwatch start
#   -> Stopwatch stop : avg.time = 3781 ms [1 counts]
#
# # Output
# success = 98.17% (4948/5040)
#
# Success pattern tree [Head 3 pieces]:
# * -> 98.17 %
# ∟ T -> 97.78 %
#   ∟ TI -> 100.00 %
#     ∟ TIL -> 100.00 %
#     ∟ TIJ -> 100.00 %
#     ∟ TIS -> 100.00 %
#     ∟ TIZ -> 100.00 %
#     ∟ TIO -> 100.00 %
#   ∟ TL -> 96.67 %
#     ∟ TLI -> 100.00 %
#     ∟ TLJ -> 100.00 %
#     ∟ TLS -> 91.67 %
#     ∟ TLZ -> 91.67 %
#     ∟ TLO -> 100.00 %
#   ∟ TJ -> 100.00 %
#     ∟ TJI -> 100.00 %
# ...

# %%
# !head -n 200 /content/sfinder_result.txt
# Out:
# # Setup Field
# X_________
# X________X
# XX____XXXX
# XX____XXXX
# XXXXX_XXXX
# XXXXX_XXXX
# XXXXX_XXXX
#
# # Initialize / User-defined
# Max clear lines: 7
# Using hold: use
# Kicks: srs
# Drop: softdrop
# Searching patterns:
#   *p7
#
# # Initialize / System
# Threads = 2
# Version = 1.43
# Necessary Pieces = 7
#
# # Enumerate pieces
# Piece pop count = 7
# Searching pattern size (duplicate) = 5040
# Searching pattern size ( no dup. ) = 5040
#
# # Search
#   -> Stopwatch start
#   -> Stopwatch stop : avg.time = 3765 ms [1 counts]
#
# # Output
# success = 98.17% (4948/5040)
#
# Success pattern tree [Head 3 pieces]:
# * -> 98.17 %
# ∟ T -> 97.78 %
#   ∟ TI -> 100.00 %
#     ∟ TIL -> 100.00 %
#     ∟ TIJ -> 100.00 %
#     ∟ TIS -> 100.00 %
#     ∟ TIZ -> 100.00 %
#     ∟ TIO -> 100.00 %
#   ∟ TL -> 96.67 %
#     ∟ TLI -> 100.00 %
#     ∟ TLJ -> 100.00 %
#     ∟ TLS -> 91.67 %
#     ∟ TLZ -> 91.67 %
#     ∟ TLO -> 100.00 %
#   ∟ TJ -> 100.00 %
#     ∟ TJI -> 100.00 %
# ...

# %%
from google.colab import files
files.download('/content/sfinder_result.txt')
